# %%
for i in range(5):
    for j in range(0,i+1):
        print("*",end=' ')
    print("\n")
for i in range(5):
    for j in range(i,4):
        print("*",end=' ')
    print("\n")
# Out:
# *
#
# * *
#
# * * *
#
# * * * *
#
# * * * * *
#
# * * * *
#
# * * *
#
# * *
#
# *

# %%
a=list(input("enter a name: "))
s=""
for i in range((len(a)-1),-1,-1):
    s=s+a[i]
print(s)
# Out:
# enter a name: ineuron
# norueni
